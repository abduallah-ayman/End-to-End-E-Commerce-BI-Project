# %%
from faker import Faker
import pandas as pd
import random
from datetime import datetime, timedelta

# %%
fake = Faker()

NUM_SELLERS = 200
NUM_CUSTOMERS = 50000
ratings = []

# %%
for seller_id in range(1, NUM_SELLERS + 1):
    num_ratings = random.randint(5, 50)
    for _ in range(num_ratings):
        customer_id = random.randint(1, NUM_CUSTOMERS)
        rating_value = random.randint(1, 5)
        review_date = fake.date_between(start_date='-3y', end_date='today')
        
        ratings.append({
            "SellerID": seller_id,
            "CustomerID": customer_id,
            "Rating": rating_value,
            "ReviewDate": review_date
        })

df = pd.DataFrame(ratings)

# %%
output_path = "D:\Portfolio\Data generation\Data\Seller\SellerRating.xlsx"
df.to_excel(output_path, index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\PanDa\AppData\Local\Temp\ipykernel_23744\4193831905.py:1: SyntaxWarning: invalid escape sequence '\P'
#   output_path = "D:\Portfolio\Data generation\Data\Seller\SellerRating.xlsx"
