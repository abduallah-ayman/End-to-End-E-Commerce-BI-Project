# %%
from faker import Faker
import pandas as pd
import random
from datetime import datetime, timedelta

# %%
fake = Faker()

NUM_SELLERS = 200
sellers = []

# %%
for _ in range(NUM_SELLERS):
    sellers.append({
        "SellerName": fake.company(),
        "RegistrationDate": fake.date_between(start_date='-5y', end_date='today')
    })

df = pd.DataFrame(sellers)

# %%
output_path = "D:\Portfolio\Data generation\Data\Seller\Seller.xlsx"
df.to_excel(output_path, index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\PanDa\AppData\Local\Temp\ipykernel_21888\2060565686.py:1: SyntaxWarning: invalid escape sequence '\P'
#   output_path = "D:\Portfolio\Data generation\Data\Seller\Seller.xlsx"
